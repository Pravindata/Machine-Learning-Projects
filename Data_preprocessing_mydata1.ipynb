# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
iris_data=load_iris()

# %%
data=pd.DataFrame(iris_data.data, columns=iris_data.feature_names)

# %%
data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
data.shape
# Out:
# (150, 4)

# %%
data.size
# Out:
# 600

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
data.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
data.corr()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
#
#                    petal width (cm)
# sepal length (cm)          0.817941
# sepal width (cm)          -0.366126
# petal length (cm)          0.962865
# petal width (cm)           1.000000

# %%
print("Skewness of Sepal l : ",data["sepal length (cm)"].skew())
print("Skewness of Sepal W : ",data["sepal width (cm)"].skew())
print("Skewness of Petal l : ",data["petal length (cm)"].skew())
print("Skewness of Petal w : ",data["petal width (cm)"].skew())
# Out:
# Skewness of Sepal l :  0.3149109566369728
# Skewness of Sepal W :  0.31896566471359966
# Skewness of Petal l :  -0.27488417975101276
# Skewness of Petal w :  -0.10296674764898116

# %%
print("Skewness of Sepal l : ",data["sepal length (cm)"].skew())
print("Skewness of Sepal l : ",sns.distplot(data["sepal length (cm)"]))
# Out:
# Skewness of Sepal l :  0.3149109566369728
# Skewness of Sepal l :  AxesSubplot(0.125,0.125;0.775x0.755)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print("Skewness of Sepal W : ",data["sepal width (cm)"].skew())
print("Skewness of Sepal w : ",sns.distplot(data["sepal width (cm)"]))
# Out:
# Skewness of Sepal W :  0.31896566471359966
# Skewness of Sepal w :  AxesSubplot(0.125,0.125;0.775x0.755)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print("Skewness of Petal l : ",data["petal length (cm)"].skew())
print("Skewness of Petal l : ",sns.distplot(data["petal length (cm)"]))
# Out:
# Skewness of Petal l :  -0.27488417975101276
# Skewness of Petal l :  AxesSubplot(0.125,0.125;0.775x0.755)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print("Skewness of Petal w : ",data["petal width (cm)"].skew())
print("Skewness of Petal w : ",sns.distplot(data["petal width (cm)"]))
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Skewness of Petal w :  -0.10296674764898116
# Skewness of Petal w :  AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print("Kurtosis of Sepal l : ",data["sepal length (cm)"].kurt())
print("Kurtosis of Sepal W : ",data["sepal width (cm)"].kurt())
print("Kurtosis of Petal l : ",data["petal length (cm)"].kurt())
print("Kurtosis of Petal w : ",data["petal width (cm)"].kurt())
# Out:
# Kurtosis of Sepal l :  -0.5520640413156395
# Kurtosis of Sepal W :  0.2282490424681929
# Kurtosis of Petal l :  -1.4021034155217518
# Kurtosis of Petal w :  -1.340603996612646

# %%
data.plot.scatter("sepal length (cm)","sepal width (cm)")
# Out:
# <AxesSubplot:xlabel='sepal length (cm)', ylabel='sepal width (cm)'>

# %%
data.plot.scatter("sepal length (cm)","petal length (cm)")
# Out:
# <AxesSubplot:xlabel='sepal length (cm)', ylabel='petal length (cm)'>

# %%
data.plot.scatter("sepal length (cm)","petal width (cm)")
# Out:
# <AxesSubplot:xlabel='sepal length (cm)', ylabel='petal width (cm)'>

# %%
data.corr()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
#
#                    petal width (cm)
# sepal length (cm)          0.817941
# sepal width (cm)          -0.366126
# petal length (cm)          0.962865
# petal width (cm)           1.000000

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data)
